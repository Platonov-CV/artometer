# %%
import pandas as pd

# %%
df = pd.read_csv("artstation_main_data.csv")

# %%
df.columns
# Out:
# Index(['Role', 'Compan Work at', 'Date Posted ', '№ Views', '№ Comments',
#        '№ Likes', 'Software Used', 'Tags Used', 'Artwork Title', 'URL'],
#       dtype='object')

# %%
df['Date Posted '].value_counts()
# Out:
# Date Posted
# a month ago     10302
# 2 months ago     9569
# 3 months ago     4871
# 9 days ago       3370
# 11 days ago      2975
# 10 days ago      2230
# 12 days ago      2143
# 13 days ago      1784
# 14 days ago      1478
# 15 days ago      1213
# 16 days ago      1121
# 17 days ago      1052
# 20 days ago      1027
# 18 days ago      1003
# 19 days ago       876
# 21 days ago       874
# 8 days ago        768
# 23 days ago       764
# 22 days ago       764
# 24 days ago       719
# 25 days ago       697
# 7 days ago        333
# 5 days ago         33
# 6 days ago         24
# 4 days ago          2
# Name: count, dtype: int64

# %%
df['№ Likes'].hist(bins=15)
# Out:
# <Axes: >

# %%
df['№ Likes'].value_counts()
# Out:
# № Likes
# 0     36410
# 1      9406
# 2      2723
# 3       808
# 4       382
# 5       146
# 6        93
# 7        54
# 8        33
# 9        14
# 11       10
# 10        9
# 12        8
# 14        5
# 13        4
# 23        2
# 15        2
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             № Views    № Comments       № Likes
# count  50109.000000  50109.000000  50109.000000
# mean     134.527949     16.031392      0.426151
# std      210.076520     20.767651      0.935985
# min        0.000000      0.000000      0.000000
# 25%       22.000000      4.000000      0.000000
# 50%       59.000000      8.000000      0.000000
# 75%      170.000000     20.000000      1.000000
# max    11143.000000    482.000000     23.000000

# %%
df.iloc[66]['URL']
# Out:
# 'https://www.artstation.com/artwork/lxYx9o\n'
